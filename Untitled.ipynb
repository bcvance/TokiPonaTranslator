# %%
"""
TODO:
- have phrase translations
- possessive adjectives not after e
- adjective noun order



S li V e O
S li V/O

moku -> verb
     -> noun

noun dictionary 
verb dictionary
"""

# %%
raw_dictionary = """a or kin
     PARTICLE (emphasis, emotion or confirmation)
akesi
     NOUN non-cute animal; reptile, amphibian
ala
     ADJECTIVE no, not, zero
alasa
     VERB hunt, forage
ale or ali
     ADJECTIVE all; abundant, countless, bountiful, every, plentiful
     NOUN abundance, everything, life, universe
     NUMBER 100
anpa
     ADJECTIVE bowing down, downward, humble, lowly, dependent
ante
     ADJECTIVE different, altered, changed, other
anu
     PARTICLE or
awen
     ADJECTIVE enduring, kept, protected, safe, waiting, staying
     PRE-VERB continuer à
e
     PARTICLE (before the direct object)
en
     PARTICLE (between multiple subjects)
esun
     NOUN market, shop, fair, bazaar, business transaction
ijo
     NOUN thing, phenomenon, object, matter
ike
     ADJECTIVE bad, negative; non-essential, irrelevant
ilo
     NOUN tool, implement, machine, device
insa
     NOUN centre, content, inside, between; internal organ, stomach
jaki
     ADJECTIVE disgusting, obscene, sickly, toxic, unclean, unsanitary
jan
     NOUN human being, person, somebody
jelo
     ADJECTIVE yellow, yellowish
jo
     VERB have, carry, contain, hold
kala
     NOUN fish, marine animal, sea creature
kalama
     VERB produce a sound; recite, utter aloud
kama
     ADJECTIVE arriving, coming, future, summoned
     PRE-VERB become, manage to, succeed in
kasi
     NOUN plant, vegetation; herb, leaf
ken
     PRE-VERB be able to, be allowed to, can, may
     ADJECTIVE possible
kepeken
     VERB use
     PREPOSITION with, by means of
kili
     NOUN fruit, vegetable, mushroom
kiwen
     NOUN hard object, metal, rock, stone
ko
     NOUN clay, clinging form, dough, semi-solid, paste, powder
kon
     NOUN air, breath; essence, spirit; hidden reality, unseen agent
kule
     ADJECTIVE colourful, pigmented, painted
kulupu
     NOUN community, company, group, nation, society, tribe
kute
     NOUN ear
     VERB hear, listen; pay attention to, obey
la
     PARTICLE (between the context phrase and the main sentence)
lape
     ADJECTIVE sleeping, resting
laso
     ADJECTIVE blue, green
lawa
     NOUN head, mind
     VERB control, direct, guide, lead, own, plan, regulate, rule
len
     NOUN cloth, clothing, fabric, textile; cover, layer of privacy
lete
     ADJECTIVE cold, cool; uncooked, raw
li
     PARTICLE (between any subject except mi alone or sina alone
     and its verb; also to introduce a new verb for the same
     subject)
lili
     ADJECTIVE little, small, short; few; a bit; young
linja
     NOUN long and flexible thing; cord, hair, rope, thread, yarn
lipu
     NOUN flat object; book, document, card, paper, record, website
loje
     ADJECTIVE red, reddish
lon
     PREPOSITION located at, present at, real, true, existing
luka
     NOUN arm, hand, tactile organ
     NUMBER five
lukin or oko
     NOUN eye
     VERB look at, see, examine, observe, read, watch
     PRE-VERB to seek, look for, try to
lupa
     NOUN door, hole, orifice, window
ma
     NOUN earth, land; outdoors, world; country, territory; soil
mama
     NOUN parent, ancestor; creator, originator; caretaker, sustainer
mani
     NOUN money, cash, savings, wealth; large domesticated animal
meli
     NOUN woman, female, feminine person; wife
mi
     SUBJECT-PRONOUN I, we
     OBJECT-PRONOUN me, us
     POSSESSIVE-PRONOUN my, our
mije
     NOUN man, male, masculine person; husband
moku
     VERB to eat, drink, consume, swallow, ingest
moli
     ADJECTIVE dead, dying
monsi
     NOUN back, behind, rear
mu
     PARTICLE (animal noise or communication)
mun
     NOUN moon, night sky object, star
musi
     ADJECTIVE artistic, entertaining, frivolous, playful, recreational
mute
     ADJECTIVE many, a lot, more, much, several, very
     NOUN quantity
nanpa
     PARTICLE -th (ordinal number)
     NOUN numbers
nasa
     ADJECTIVE unusual, strange; foolish, crazy; drunk, intoxicated
nasin
     NOUN way, custom, doctrine, method, path, road
nena
     NOUN bump, button, hill, mountain, nose, protuberance
ni
     ADJECTIVE that, this
nimi
     NOUN name, word
noka
     NOUN foot, leg, organ of locomotion; bottom, lower part
o
     PARTICLE hey! O! (vocative or imperative)
olin
     VERB love, have compassion for, respect, show affection to
ona
     SUBJECT-PRONOUN he, she, it, they
     OBJECT-PRONOUN him, her, it, them
     POSSESSIVE-PRONOUN his, her, its, their
open
     VERB begin, start; open; turn on
pakala
     ADJECTIVE botched, broken, damaged, harmed, messed up
     VERB mess up, screw up, botch
pali
     VERB do, take action on, work on; build, make, prepare
palisa
     NOUN long hard thing; branch, rod, stick
pan
     NOUN cereal, grain; barley, corn, oat, rice, wheat; bread, pasta
pana
     VERB give, send, emit, provide, put, release
pi
     PARTICLE of
pilin
     NOUN heart (physical or emotional)
     ADJECTIVE feeling (an emotion, a direct experience)
pimeja
     ADJECTIVE black, dark, unlit
pini
     ADJECTIVE ago, completed, ended, finished, past
pipi
     NOUN bug, insect, ant, spider
poka
     NOUN hip, side; next to, nearby, vicinity
poki
     NOUN container, bag, bowl, box, cup, cupboard, drawer, vessel
pona
     ADJECTIVE good, positive, useful; friendly, peaceful; simple
pu
     ADJECTIVE interacting with the official Toki Pona book
sama
     ADJECTIVE same, similar; each other; sibling, peer, fellow
     PREPOSITION as, like
seli
     ADJECTIVE fire; cooking element, chemical reaction, heat source
selo
     NOUN outer form, outer layer; bark, peel, shell, skin; boundary
seme
     PARTICLE what? which?
sewi
     NOUN area above, highest part, something elevated
     ADJECTIVE awe-inspiring, divine, sacred, supernatural
sijelo
     NOUN body (of person or animal), physical state, torso
sike
     NOUN round or circular thing; ball, circle, cycle, sphere, wheel
     ADJECTIVE of one year
sin or namako
     ADJECTIVE new, fresh; additional, another, extra
sina
     SUBJECT-PRONOUN you
     OBJECT-PRONOUN you
     POSSESSIVE-PRONOUN your
sinpin
     NOUN face, foremost, front, wall
sitelen
     NOUN image, picture, representation, symbol, mark, writing
sona
     VERB know, be skilled in, be wise about, have information on
     PRE-VERB to know how to
soweli
     NOUN animal, beast, land mammal
suli
     ADJECTIVE big, heavy, large, long, tall; important; adult
suno
     NOUN sun; light, brightness, glow, radiance, shine; light source
supa
     NOUN horizontal surface, thing to put or rest something on
suwi
     ADJECTIVE sweet, fragrant; cute, innocent, adorable
tan
     PREPOSITION by, from, because of
taso
     PARTICLE but, however
     ADJECTIVE only
tawa
     PREPOSITION going to, toward; for; from the perspective of
     ADJECTIVE moving
telo
     NOUN water, liquid, fluid, wet substance; beverage
tenpo
     NOUN time, duration, moment, occasion, period, situation
toki
     VERB communicate, say, speak, say, talk, use language, think
tomo
     NOUN indoor space; building, home, house, room
tu
     NUMBER two
unpa
     VERB have sexual or marital relations with
uta
     NOUN mouth, lips, oral cavity, jaw
utala
     VERB battle, challenge, compete against, struggle against
walo
     ADJECTIVE white, whitish; light-coloured, pale
wan
     ADJECTIVE unique, united
     NUMBER one
waso
     NOUN bird, flying creature, winged animal
wawa
     ADJECTIVE strong, powerful; confident, sure; energetic, intense
weka
     ADJECTIVE absent, away, ignored
wile
     PRE-VERB must, need, require, should, want, wish"""

# %%
dictionary = {}

# %%
parts_of_speech = "NOUN NUMBER VERB ADJECTIVE PRE-VERB PREPOSITION PARTICLE".split()
dictionary_lines = raw_dictionary.split("\n")

# %%
def line_to_key_value(line):
    line = line.strip()
    if '(' in line:
        line = line[0:line.find("(")] + line[line.find(")")+1:]
    key = line.split()[0]
    values = ' '.join(line.split()[1:]).replace(';',',').replace(' or',',').split(',')

    return key, values
    
    

line_to_key_value('PARTICLE (emphasis, emotion or confirmation)')
# Out:
# ('PARTICLE', [''])

# %%
tokipona_words = [] 
for line in dictionary_lines: 
    if line[0] == " ": #
        key,value = line_to_key_value(line)
        for word in tokipona_words:
            if word in dictionary:
                dictionary[word][key] = value
            else:
                dictionary[word] = {key:value} 
    else: 
        if "or" in line:
            tokipona_words = [word.strip() for word in line.split("or")]
        else:
            tokipona_words = [line]
print(dictionary)
# Out:
# {'a': {'PARTICLE': ['']}, 'kin': {'PARTICLE': ['']}, 'akesi': {'NOUN': ['non-cute animal', ' reptile', ' amphibian']}, 'ala': {'ADJECTIVE': ['no', ' not', ' zero']}, 'alasa': {'VERB': ['hunt', ' forage']}, 'ale': {'ADJECTIVE': ['all', ' abundant', ' countless', ' bountiful', ' every', ' plentiful'], 'NOUN': ['abundance', ' everything', ' life', ' universe'], 'NUMBER': ['100']}, 'ali': {'ADJECTIVE': ['all', ' abundant', ' countless', ' bountiful', ' every', ' plentiful'], 'NOUN': ['abundance', ' everything', ' life', ' universe'], 'NUMBER': ['100']}, 'anpa': {'ADJECTIVE': ['bowing down', ' downward', ' humble', ' lowly', ' dependent']}, 'ante': {'ADJECTIVE': ['different', ' altered', ' changed', ' other']}, 'anu': {'PARTICLE': ['or']}, 'awen': {'ADJECTIVE': ['enduring', ' kept', ' protected', ' safe', ' waiting', ' staying'], 'PRE-VERB': ['continuer à']}, 'e': {'PARTICLE': ['']}, 'en': {'PARTICLE': ['']}, 'esun': {'NOUN': ['market', ' shop', ' fair', ' bazaar', ' business transaction']}, 'ijo': {'NOUN': ['thing', ' phenomenon', ' object', ' matter']}, 'ike': {'ADJECTIVE': ['bad', ' negative', ' non-essential', ' irrelevant']}, 'ilo': {'NOUN': ['tool', ' implement', ' machine', ' device']}, 'insa': {'NOUN': ['centre', ' content', ' inside', ' between', ' internal', 'gan', ' stomach']}, 'jaki': {'ADJECTIVE': ['disgusting', ' obscene', ' sickly', ' toxic', ' unclean', ' unsanitary']}, 'jan': {'NOUN': ['human being', ' person', ' somebody']}, 'jelo': {'ADJECTIVE': ['yellow', ' yellowish']}, 'jo': {'VERB': ['have', ' carry', ' contain', ' hold']}, 'kala': {'NOUN': ['fish', ' marine animal', ' sea creature']}, 'kalama': {'VERB': ['produce a sound', ' recite', ' utter aloud']}, 'kama': {'ADJECTIVE': ['arriving', ' coming', ' future', ' summoned'], 'PRE-VERB': ['become', ' manage to', ' succeed in']}, 'kasi': {'NOUN': ['plant', ' vegetation', ' herb', ' leaf']}, 'ken': {'PRE-VERB': ['be able to', ' be allowed to', ' can', ' may'], 'ADJECTIVE': ['possible']}, 'kepeken': {'VERB': ['use'], 'PREPOSITION': ['with', ' by means of']}, 'kili': {'NOUN': ['fruit', ' vegetable', ' mushroom']}, 'kiwen': {'NOUN': ['hard object', ' metal', ' rock', ' stone']}, 'ko': {'NOUN': ['clay', ' clinging form', ' dough', ' semi-solid', ' paste', ' powder']}, 'kon': {'NOUN': ['air', ' breath', ' essence', ' spirit', ' hidden reality', ' unseen agent']}, 'kule': {'ADJECTIVE': ['colourful', ' pigmented', ' painted']}, 'kulupu': {'NOUN': ['community', ' company', ' group', ' nation', ' society', ' tribe']}, 'kute': {'NOUN': ['ear'], 'VERB': ['hear', ' listen', ' pay attention to', ' obey']}, 'la': {'PARTICLE': ['']}, 'lape': {'ADJECTIVE': ['sleeping', ' resting']}, 'laso': {'ADJECTIVE': ['blue', ' green']}, 'lawa': {'NOUN': ['head', ' mind'], 'VERB': ['control', ' direct', ' guide', ' lead', ' own', ' plan', ' regulate', ' rule']}, 'len': {'NOUN': ['cloth', ' clothing', ' fabric', ' textile', ' cover', ' layer of privacy']}, 'lete': {'ADJECTIVE': ['cold', ' cool', ' uncooked', ' raw']}, 'li': {'PARTICLE': ['PARTICLE (between any subject except mi alone', ' sina alone'], 'and': ['its verb', ' also to introduce a new verb for the same'], 'subject)': ['']}, 'lili': {'ADJECTIVE': ['little', ' small', ' short', ' few', ' a bit', ' young']}, 'linja': {'NOUN': ['long and flexible thing', ' cord', ' hair', ' rope', ' thread', ' yarn']}, 'lipu': {'NOUN': ['flat object', ' book', ' document', ' card', ' paper', ' record', ' website']}, 'loje': {'ADJECTIVE': ['red', ' reddish']}, 'lon': {'PREPOSITION': ['located at', ' present at', ' real', ' true', ' existing']}, 'luka': {'NOUN': ['arm', ' hand', ' tactile', 'gan'], 'NUMBER': ['five']}, 'lukin': {'NOUN': ['eye'], 'VERB': ['look at', ' see', ' examine', ' observe', ' read', ' watch'], 'PRE-VERB': ['to seek', ' look for', ' try to']}, 'oko': {'NOUN': ['eye'], 'VERB': ['look at', ' see', ' examine', ' observe', ' read', ' watch'], 'PRE-VERB': ['to seek', ' look for', ' try to']}, 'lupa': {'NOUN': ['door', ' hole', '', 'ifice' ...

# %%
poem = """ijo li moku e mi.
mi wile pakala.
pimeja li tawa insa kon mi.
jan ala li ken sona e pilin ike mi.
toki musi o, sina jan pona mi wan taso.
telo pimeja ni li telo loje mi, li ale mi.
tenpo ale la pimeja li lon."""

"""
mi moku = I eat
sina moku = you eat
ona li moku = It eats

mi wawa = I am strong
sina wawa = you are strong
ona li wawa = It is strong

"""
# Out:
# '\nmi moku = I eat\nsina moku = you eat\nona li moku = It eats\n\nmi wawa = I am strong\nsina wawa = you are strong\nona li wawa = It is strong\n\n'

# %%
# input sentence -> phrase -> translated sentence
#'ijo li moku e mi'

# class Phrase:
#     def __init__(self):
#         self.subject = None
#         self.verb = None
#         self.verb_or_adjective = None
#         self.object = None
#         self.context = None

# def tokenize_and_tag(line):
"""
split on 'la' -> before 0 context
split rest on 'li' - > 0 becomes subject OR if first word is mi or sina
split rest on 'e' 
   -> 
   
'wawa': {'ADJECTIVE': ['strong', ' powerful', ' confident', ' sure', ' energetic', ' intense']}, 
'weka': {'ADJECTIVE': ['absent', ' away', ' ignored']}, 
'wile': {'PRE-VERB': ['must', ' need', ' require', ' should', ' want', ' wish']}}

"""
# Out:
# "\nsplit on 'la' -> before 0 context\nsplit rest on 'li' - > 0 becomes subject OR if first word is mi or sina\nsplit rest on 'e' \n   -> \n   \n'wawa': {'ADJECTIVE': ['strong', ' powerful', ' confident', ' sure', ' energetic', ' intense']}, \n'weka': {'ADJECTIVE': ['absent', ' away', ' ignored']}, \n'wile': {'PRE-VERB': ['must', ' need', ' require', ' should', ' want', ' wish']}}\n\n"

# %%
import random

input_lines = poem.replace(",", ".").split(".")
output = [] # an ala ken sona pilin ike
for line in input_lines: # line = jan ala li ken sona e pilin ike mi. i = 8
    #     phrase = tokenize_and_tag(line)
    #     translated_sentence = translate(phrase)
    # translation = []
    choice = None
    last_particle = None
    last_particle_index = None # 5
    tokens = line.split()
    for i, token in enumerate(tokens): 
        #print(output)
        if token in ["la", "li", "e"]:
            #print(f"hello we are here{token}")
            last_particle = token
            last_particle_index = i
            choice = None
        else:
            #print(f"HERE {token}")
            if token in dictionary:
                #print(f"hi {token}")
                if choice and choice == "PRE-VERB": # pre verb followed by verb rule
                    if "VERB" in dictionary[token]:
                        choice = "VERB"
                        word = random.choice(dictionary[token][choice])
                        #print(f"word: {word}")
                        output.append(word)
                    else:
                        #print(f"VERB not in dictionary[{token}]")
                        choice = random.choice(list(dictionary[token]))
                        word = random.choice(dictionary[token][choice])
                        #print(f"word: {word}")
                        output.append(word)
                elif "SUBJECT-PRONOUN" in dictionary[token]:
                    if last_particle and last_particle == "e" and i > 0 and not tokens[i-1] == "e": # possessive adj rule
                        choice = "POSSESSIVE-PRONOUN"
                        word = random.choice(dictionary[token][choice])
                        # insert word
                        number_of_preceeding_nouns = i - last_particle_index - 1
                        output = output[:-number_of_preceeding_nouns] + [word] + output[-number_of_preceeding_nouns:]
                        
                    elif i > 0 and tokens[i-1] == "e": # object pronoun rule
                        choice = "OBJECT-PRONOUN"
                        word = random.choice(dictionary[token][choice])
                        #print(f"word: {word}")
                        output.append(word)
                    else: 
                        choice = "SUBJECT-PRONOUN"
                        word = random.choice(dictionary[token][choice])
                        #print(f"word: {word}")
                        output.append(word)
                    
                else:
                    choice = random.choice(list(dictionary[token]))
                    word = random.choice(dictionary[token][choice])
                    #print(f"word: {word}")
                    output.append(word)
#                 print(token, dictionary[token])
    output.append("\n")
#     print("\n")
output = ' '.join(output)
print(output)
print(poem)
# Out:
#  object  ingest  us
#   we must  screw up
#  black moving  stomach air  we
#   somebody  zero possible  be skilled in  our heart  irrelevant
#   speak  frivolous hey! O!
#  you  somebody  friendly  we one but
#  water  unlit that  wet substance  reddish  we
#   universe  we
#   period abundance  unlit  real
#
#
# ijo li moku e mi.
# mi wile pakala.
# pimeja li tawa insa kon mi.
# jan ala li ken sona e pilin ike mi.
# toki musi o, sina jan pona mi wan taso.
# telo pimeja ni li telo loje mi, li ale mi.
# tenpo ale la pimeja li lon.

# %%
I am devoured.
I must destroy.
Darkness fills my soul.
No one can understand my suffering.
O poetry! My only friend.
This ink is my blood, is my life.
And Darkness shall reign forevermore.

# %%
l = [1, 2, 3]
l[:-2]
# Out:
# [1]
